# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting styles
# %matplotlib inline
sns.set(style='whitegrid')

# %% [markdown]
# Load the Data set

# %%
df = pd.read_csv('../data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Basic Dataset Overview

# %%
# Check dataset shape and data types
print("Shape:", df.shape)
df.info()
# Out:
# Shape: (1470, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %%
# View statistical summary
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Null & Duplicate Check

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# Convert Object Columns to Categories

# %%
# Convert object (text) columns to categorical for efficiency
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype('category')

df.dtypes.head(10)
# Out:
# Age                    int64
# Attrition           category
# BusinessTravel      category
# DailyRate              int64
# Department          category
# DistanceFromHome       int64
# Education              int64
# EducationField      category
# EmployeeCount          int64
# EmployeeNumber         int64
# dtype: object

# %% [markdown]
# Value Counts for Target Column

# %%
# Target column distribution
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %% [markdown]
# Visualize Attrition Counts

# %%
# Bar chart of Attrition
sns.countplot(data=df, x='Attrition')
plt.title('Employee Attrition Distribution')
# Out:
# Text(0.5, 1.0, 'Employee Attrition Distribution')

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df, x='JobRole', hue='Attrition')
plt.title('Attrition by Job Role')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Healthcare Representative'),
#   Text(1, 0, 'Human Resources'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manager'),
#   Text(4, 0, 'Manufacturing Director'),
#   Text(5, 0, 'Research Director'),
#   Text(6, 0, 'Research Scientist'),
#   Text(7, 0, 'Sales Executive'),
#   Text(8, 0, 'Sales Representative')])

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data=df[df['Attrition'] == 'Yes'], x='Age', label='Yes')
sns.kdeplot(data=df[df['Attrition'] == 'No'], x='Age', label='No')
plt.title('Age Distribution by Attrition')
plt.legend()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome')
plt.title('Monthly Income by Attrition')
# Out:
# Text(0.5, 1.0, 'Monthly Income by Attrition')

# %%
# Encode categorical columns temporarily for correlation
df_encoded = df.copy()
for col in df_encoded.select_dtypes(include='category').columns:
    df_encoded[col] = df_encoded[col].cat.codes

# Correlation matrix
plt.figure(figsize=(16,12))
corr = df_encoded.corr()
sns.heatmap(corr, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='Department', hue='Attrition')
plt.title('Attrition by Department')
plt.xticks(rotation=15)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Human Resources'),
#   Text(1, 0, 'Research & Development'),
#   Text(2, 0, 'Sales')])

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Gender', hue='Attrition')
plt.title('Attrition by Gender')
# Out:
# Text(0.5, 1.0, 'Attrition by Gender')

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='BusinessTravel', hue='Attrition')
plt.title('Attrition by Business Travel Frequency')
plt.xticks(rotation=15)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Non-Travel'),
#   Text(1, 0, 'Travel_Frequently'),
#   Text(2, 0, 'Travel_Rarely')])

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='OverTime', hue='Attrition')
plt.title('Attrition by Overtime')
# Out:
# Text(0.5, 1.0, 'Attrition by Overtime')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='WorkLifeBalance', hue='Attrition')
plt.title('Attrition by Work-Life Balance Rating')
# Out:
# Text(0.5, 1.0, 'Attrition by Work-Life Balance Rating')

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df, x='YearsAtCompany', hue='Attrition', multiple='stack', bins=20)
plt.title('Years at Company vs Attrition')
# Out:
# Text(0.5, 1.0, 'Years at Company vs Attrition')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='JobSatisfaction', hue='Attrition')
plt.title('Attrition by Job Satisfaction (1 = Low, 4 = High)')
# Out:
# Text(0.5, 1.0, 'Attrition by Job Satisfaction (1 = Low, 4 = High)')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='EducationField', hue='Attrition')
plt.title('Attrition by Education Field')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Human Resources'),
#   Text(1, 0, 'Life Sciences'),
#   Text(2, 0, 'Marketing'),
#   Text(3, 0, 'Medical'),
#   Text(4, 0, 'Other'),
#   Text(5, 0, 'Technical Degree')])

# %%
# Encode 'Attrition' for coloring
df_plot = df[['Age', 'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'Attrition']].copy()
df_plot['Attrition'] = df_plot['Attrition'].map({'Yes': 1, 'No': 0})

sns.pairplot(df_plot, hue='Attrition', palette='Set1', diag_kind='kde')

# %%
# Use the earlier encoded DataFrame
target_corr = corr['Attrition'].drop('Attrition').abs().sort_values(ascending=False).head(10)

plt.figure(figsize=(8,5))
sns.barplot(x=target_corr.values, y=target_corr.index, palette='mako')
plt.title('Top 10 Features Most Correlated with Attrition')
plt.xlabel('Absolute Correlation')
# Out:
# /var/folders/7p/yl9yd65n5qv0xybjl0t5td1c0000gn/T/ipykernel_8302/3652126345.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=target_corr.values, y=target_corr.index, palette='mako')
# Text(0.5, 0, 'Absolute Correlation')
